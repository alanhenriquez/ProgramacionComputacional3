# %% [markdown]
# <a href="https://colab.research.google.com/github/alanhenriquez/ProgramacionComputacional3/blob/main/tarea_semana9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
tarjetas = pd.read_csv("/content/trx_tarjetas_credito.csv", sep=",", encoding="utf-8")
print(tarjetas)
print("\n" + "\n")

#Utlizacion de tarjetas de credito por sexo
genero = pd.crosstab(index = tarjetas["Gender"], columns = "fr")
print("#Utlizacion de tarjetas de credito por sexo------------------------")
print(genero)
print("\n" + "\n")

#Total en dolares utilizados diferenciando tarjetas de credito por ciudad
ciudad = (tarjetas.groupby(["City", "Card Type"]).sum())
print("#Total en dolares utilizados diferenciando tarjetas de credito por ciudad------------------------")
print(ciudad)
print("\n" + "\n")

#Total utilizado por tipo de gasto
gasto = (tarjetas.groupby(["Exp Type"]).sum().groupby(level = [0]).cumsum())
print("#Total utilizado por tipo de gasto------------------------")
print(gasto)
print("\n" + "\n")

tabla = pd.crosstab(index=tarjetas["Gender"], columns="fr")
plt.pie(tabla, labels=tabla.index, autopct="%0.1f %%")
plt.xlabel("Utilizacion de tarjetas por sexo")
plt.show()

tabla = pd.crosstab(index=tarjetas["Card Type"], columns="fr")
plt.pie(tabla, labels=tabla.index, autopct="%0.1f %%")
plt.xlabel("Utilizacion de tarjetas por sexo")
plt.show()

tabla = pd.crosstab(index=tarjetas["Exp Type"], columns="fr")
plt.pie(tabla, labels=tabla.index, autopct="%0.1f %%")
plt.xlabel("Utilizacion de tarjetas por sexo")
plt.show()
# Out:
#                         City       Date  Card Type Exp Type Gender  Amount
# 0               Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2           Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4           Bengaluru, India   5-May-15       Gold    Bills      F  171574
# ...                      ...        ...        ...      ...    ...     ...
# 26047         Kolkata, India  22-Jun-14     Silver   Travel      F  128191
# 26048            Pune, India   3-Aug-14  Signature   Travel      M  246316
# 26049       Hyderabad, India  16-Jan-15     Silver   Travel      M  265019
# 26050          Kanpur, India  14-Sep-14     Silver   Travel      M   88174
# 26051       Hyderabad, India  19-Oct-13  Signature    Bills      M  184410
#
# [26052 rows x 6 columns]
#
#
#
# #Utlizacion de tarjetas de credito por sexo------------------------
# col_0      fr
# Gender
# F       13680
# M       12372
#
#
#
# #Total en dolares utilizados diferenciando tarjetas de credito por ciudad------------------------
#                             Amount
# City             Card Type
# Achalpur, India  Gold       679992
#                  Platinum   178612
#                  Signature  547005
#                  Silver     201032
# Adilabad, India  Gold        49020
# ...                            ...
# Zira, India      Signature  218424
#                  Silver      98224
# Zirakpur, India  Platinum   549663
# Zunheboto, India Signature   89271
#                  Silver     377158
#
# [3104 rows x 1 columns]
#
#
#
# #Total utilizado por tipo de gasto------------------------
#                   Amount
# Exp Type
# Bills          907072473
# Entertainment  726437536
# Food           824724009
# Fuel           789135821
# Grocery        718207923
# Travel         109255611
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
